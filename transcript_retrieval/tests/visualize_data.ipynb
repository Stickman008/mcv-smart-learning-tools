# %%
import pandas as pd

# %%
df = pd.read_csv("../data/labeled/labeled_transcript_01.csv", index_col=0)
df.head()
# Out:
#                                                 text  \
# 0  จุดจุดจุด อ่ะก่อนอื่น คนเรือง เลือดสำคัญต่อก็ค...
# 1  คือเราวิชาแบกในสามส่วนแล้วมันก็ตอบแล้วมันก็สลา...
# 2  ภายนอกก็คือจะตอบส่วนสไตล์วิชา เอ่อ น้อง อ่านหน...
# 3  มี tina อย่างเดียว สองเจ็ด สลายสามารถโดนความรู...
# 4  โอ๊ตลูกแตะลูกอาจารย์อิรักสักคนนึงแปะมาขนาด เอ่...
#
#                                          edited_text          start_time  \
# 0  จุดจุดจุด อ่ะ ก่อนอื่น พูดเรื่อง เรื่องสำคัญก่...  2023-12-25 0:00:04
# 1  คือเราวิชาแบ่งออกเป็นสามส่วนแล้วมันสอบ แล้วก็ส...  2023-12-25 0:01:15
# 2  finalก็คือจะสอบส่วนสุดท้ายของวิชา เอ่อ เนาะ อ่...  2023-12-25 0:02:10
# 3  signal อย่างเดียว สอบเสร็จ สลายสามารถโยนความรู...  2023-12-25 0:03:17
# 4  โพสต์รูปแปะรูปอาจารย์ที่รักสักคนนึงแปะมาก็ได้ ...  2023-12-25 0:04:17
#
#             stop_time  total_time  token_count  keyword_linear program  \
# 0  2023-12-25 0:01:13       28154          107                       0
# ...

# %%
df.columns
# Out:
# Index(['text', 'edited_text', 'start_time', 'stop_time', 'total_time',
#        'token_count', 'keyword_linear program',
#        'keyword_Assumption of linear program',
#        'keyword_standard form of linear program',
#        'keyword_basic feasible solution', 'keyword_direction of unboundedness',
#        'question_optimization เอาไปใช้ทำอะไร',
#        'question_ประเภทของปัญหา optimization แบบ dynamic กับ static ต่างกันยังไง',
#        'question_ทำไม feasible region ของ linear program ถึงเป็น convex set ทั้งหมด',
#        'question_จะเปลี่ยน constraints เป็น standard form ยังไง',
#        'question_direction of unboundedness หายังไง'],
#       dtype='object')
