# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import sys
import pandas as pd
from sentence_transformers import SentenceTransformer

sys.path.append("../")
from evaluation.evaluate import Evaluation

# %%
df = pd.read_csv("../data/labeled/labeled_transcript_04.csv", index_col=0)

# %%
model_name = 'sentence-transformers/paraphrase-multilingual-mpnet-base-v2'
# model_name = "D:/Chula/Year4_2/capstone/mcv-smart-learning-tools/transcript_retrieval/simcse/saved_model/simcse-model-thai-version-1"
max_seq_length=128

model = SentenceTransformer(model_name)
model.max_seq_length = max_seq_length

# %%
evaluation = Evaluation()
evaluation.get_st_report(df, model, k_list=[10, 5, 3, 1])
# evaluation.get_st_report(df, model, k_list=[10])
# evaluation.mean_hit_k([49, 143, 107, 100, 54, 130, 95, 131, 122, 48], [49, 50, 51], 10)
# evaluation.mean_average_precision_k([49, 143, 107, 100, 54, 130, 95, 131, 122, 48], [49, 50, 51], 10)
# Out:
# Embedding context
# Batches:   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
# [[98, 94, 80, 82, 99, 84, 120, 103, 119, 53], [176, 159, 160, 169, 162, 202, 179, 172, 165, 167], [186, 207, 188, 197, 172, 185, 182, 187, 196, 105], [94, 82, 180, 191, 120, 184, 99, 188, 78, 182], [82, 156, 187, 179, 159, 84, 94, 64, 85, 125], [114, 161, 156, 103, 104, 85, 118, 94, 88, 125], [85, 161, 64, 56, 82, 88, 66, 97, 179, 55], [85, 104, 186, 172, 125, 156, 179, 162, 187, 64], [160, 159, 161, 169, 202, 162, 158, 154, 156, 172], [75, 72, 53, 57, 112, 78, 68, 120, 186, 183]]
# [[97, 98, 99, 100, 101, 103, 104, 105, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118], [159, 160, 161, 162, 167, 168, 169, 171, 176, 177, 178, 179, 180], [183, 184, 185, 186], [188, 189, 190, 191, 192], [80, 81, 82, 83, 84, 85, 86, 87, 88], [97, 98, 99, 100, 101, 103, 104, 105], [80, 81, 82, 83, 84, 85, 86, 87, 88], [121, 122, 123, 124, 125, 126, 127, 128, 129], [161, 162, 163, 164, 165, 166, 167, 168, 169, 170, 171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181], [183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199, 200, 204, 205, 206, 207]]
# [[98, 94, 80, 82, 99], [176, 159, 160, 169, 162], [186, 207, 188, 197, 172], [94, 82, 180, 191, 120], [82, 156, 187, 179, 159], [114, 161, 156, 103, 104], [85, 161, 64, 56, 82], [85, 104, 186, 172, 125], [160, 159, 161, 169, 202], [75, 72, 53, 57, 112]]
# [[97, 98, 99, 100, 101, 103, 104, 105, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118], [159, 160, 161, 162, 167, 168, 169, 171, 176, 177, 178, 179, 180], [183, 184, 185, 186], [188, 189, 190, 191, 192], [80, 81, 82, 83, 84, 85, 86, 87, 88], [97, 98, 99, 100, 101, 103, 104, 105], [80, 81, 82, 83, 84, 85, 86, 87, 88], [121, 122, 123, 124, 125, 126, 127, 128, 129], [161, 162, 163, 164, 165, 166, 167, 168, 169, 170, 171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181], [183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199, 200, 204, 205, 206, 207]]
# [[98, 94, 80], [176, 159, 160], [186, 207, 188], [94, 82, 180], [82, 156, 187], [114, 161, 156], [85, 161, 64], [85, 104, 186], [160, 159, 161], [75, 72, 53]]
# [[97, 98, 99, 100, 101, 103, 104, 105, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118], [159, 160, 161, 162, 167, 168, 169, 171, 176, 177, 178, 179, 180], [183, 184, 185, 186], [188, 189, 190, 191, 192], [80, 81, 82, 83, 84, 85, 86, 87, 88], [97, 98, 99, 100, 101, 103, 104, 105], [80, 81, 82, 83, 84, 85, 86, 87, 88], [121, 122, 123, 124, 125, 126, 127, 128, 129], [161, 162, 163, 164, 165, 166, 167, 168, 169, 170, 171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181], [183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199, 200, 204, 205, 206, 207]]
# [[98], [176], [186], [94], [82], [114], [85], [85], [160], [75]]
# [[97, 98, 99, 100, 101, 103, 104, 105, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118], [159, 160, 161, 162, 167, 168, 169, 171, 176, 177, 178, 179, 180], [183, 184, 185, 186], [188, 189, 190, 191, 192], [80, 81, 82, 83, 84, 85, 86, 87, 88], [97, 98, 99, 100, 101, 103, 104, 105], [80, 81, 82, 83, 84, 85, 86, 87, 88], [121, 122, 123, 124, 125, 126, 127, 128, 129], [161, 162, 163, 164, 165, 166, 167, 168, 169, 170, 171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181], [183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199, 200, 204, 205, 206, 207]]
# {'number_of_embedding_entry': 221,
#  'embedding_time': 46.69350218772888,
#  'embedding_time_per_entry': 0.21128281532908996,
#  'mean_hit@10': 1.0,
#  'map@10': 0.19707605820105817,
#  'mean_hit@5': 0.9,
#  'map@5': 0.23966666666666664,
#  'mean_hit@3': 0.6,
#  'map@3': 0.2444444444444444,
#  'mean_hit@1': 0.5,
#  'map@1': 0.5}

# %%
df.iloc[[49, 50, 51]].text.tolist()
# Out:
# ['ให้ตัวตัว optimization กับแต่อยู่ติดกันนะคะก็เลยสลับนิดนึง มีคำถามอะไรไหมเอ่ยตอน ยังไม่มี ยังไม่มีใช่ โอเคนะ มีกังวลไหมมีกังวล ไม่มีสบายมา มาดีใจมากที่ได้เจอนะคะปีที่แล้วนะอาจารย์แบบมาสอนพาสสองวันแรกมานี่ต้องเต็มแน่นั่งอ่านไม่น่าสปอยเลยนะเดี๋ยวจะไม่มาเรียนกันนะคะแต่ว่าก็อยากให้มาเรียนนะ แต่ก็ไม่รู้ไงว่า',
#  'reference ตัวเป็นไงเดี๋ยวเดี๋ยววันนี้ท้ายคาบจะให้เราช่วยตอบอาจารย์หน่อยว่าเราตัวเราแบบมีสไตล์การเรียนแบบไหนนะเดี๋ยวท้ายคาบนะนะ วันนี้นะคะเราจะเริ่มเนื้อหากันเลยละกันเนาะนะคะ psi ซึ่งก็ยังเป็นอินโทรซิกแนลหน่อยหน่อยนะนะคะก็สบายสบายวันนี้ถือว่ามาทำความรู้จักแต่ก็อาจจะมีคนที่รู้จักเรื่องของตัว signal อยู่บ้างแล้วเนาะใช่ไหมคะมีใครเคยทำอินดิเรื่อง เสียงอะไรนะมีใครเคยทำนะสิเรื่องเสียง เอ่อ ไปแล้วสบายแล้วฉันเรียนจบแล้วแหละค่ะ',
#  'โอเค มันต้องเร็วนะว่าเต้าใหญ่มากนะคะ โอเคเดี๋ยวทีนี้ก็จริงจริงก็คงไม่ไม่ต้องพูดพล่ามมากนะอันนี้มันเป็นอินโทรเพราะว่าปีที่แล้วมันไปอยู่กลางกลางเนาะนะคะก็อย่างที่บอกแหละว่าในพาร์ทที่เป็น ในพาร์ทที่เป็นเลคเชอร์นะคะ ก็จะเหมือนหลักหลักเลยก็จะมีเรื่องของ fundamental final posting หลักก็จะเป็นในเรื่องของผู้ af นั่นแหละแล้วก็การ analysis นะคะ แล้วก็']
