# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import sys
import pandas as pd
from sentence_transformers import SentenceTransformer

sys.path.append("../")
from evaluation.evaluate import Evaluation

# %%
df = pd.read_csv("../data/labeled/labeled_transcript_01.csv", index_col=0)

# %%
model_name = 'sentence-transformers/paraphrase-multilingual-mpnet-base-v2'
# model_name = "D:/Chula/Year4_2/capstone/mcv-smart-learning-tools/transcript_retrieval/simcse/saved_model/simcse-model-thai-version-1"
max_seq_length=128

model = SentenceTransformer(model_name)
model.max_seq_length = max_seq_length

# %%
evaluation = Evaluation()
evaluation.get_st_report(df, model, k_list=[10, 5, 3, 1])
# evaluation.get_st_report(df, model, k_list=[10])
# evaluation.mean_hit_k([49, 143, 107, 100, 54, 130, 95, 131, 122, 48], [49, 50, 51], 10)
# evaluation.mean_average_precision_k([49, 143, 107, 100, 54, 130, 95, 131, 122, 48], [49, 50, 51], 10)
# Out:
# Embedding context
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
# [[49, 143, 107, 100, 54, 130, 95, 131, 122, 48], [51, 131, 130, 148, 49, 54, 115, 143, 44, 73], [80, 49, 143, 130, 54, 100, 79, 11, 41, 47], [115, 145, 113, 63, 112, 130, 111, 64, 117, 65], [54, 65, 64, 130, 133, 68, 101, 61, 154, 131], [49, 17, 11, 42, 16, 15, 14, 30, 2, 79], [17, 49, 33, 11, 16, 30, 42, 115, 145, 113], [107, 64, 122, 47, 59, 68, 63, 61, 54, 121], [80, 79, 81, 103, 94, 20, 42, 47, 115, 51], [54, 64, 65, 130, 133, 68, 101, 154, 131, 63]]
# [[49, 50, 51], [51, 52, 53, 54], [79, 80, 81], [117, 118, 119, 120, 121, 122, 123, 124, 125], [130, 131, 132, 133, 134], [11, 12, 13, 14], [27], [58], [82, 83, 84, 85, 86, 87, 88, 89, 90], [135, 136, 137, 138, 139]]
# [[49, 143, 107, 100, 54], [51, 131, 130, 148, 49], [80, 49, 143, 130, 54], [115, 145, 113, 63, 112], [54, 65, 64, 130, 133], [49, 17, 11, 42, 16], [17, 49, 33, 11, 16], [107, 64, 122, 47, 59], [80, 79, 81, 103, 94], [54, 64, 65, 130, 133]]
# [[49, 50, 51], [51, 52, 53, 54], [79, 80, 81], [117, 118, 119, 120, 121, 122, 123, 124, 125], [130, 131, 132, 133, 134], [11, 12, 13, 14], [27], [58], [82, 83, 84, 85, 86, 87, 88, 89, 90], [135, 136, 137, 138, 139]]
# [[49, 143, 107], [51, 131, 130], [80, 49, 143], [115, 145, 113], [54, 65, 64], [49, 17, 11], [17, 49, 33], [107, 64, 122], [80, 79, 81], [54, 64, 65]]
# [[49, 50, 51], [51, 52, 53, 54], [79, 80, 81], [117, 118, 119, 120, 121, 122, 123, 124, 125], [130, 131, 132, 133, 134], [11, 12, 13, 14], [27], [58], [82, 83, 84, 85, 86, 87, 88, 89, 90], [135, 136, 137, 138, 139]]
# [[49], [51], [80], [115], [54], [49], [17], [107], [80], [54]]
# [[49, 50, 51], [51, 52, 53, 54], [79, 80, 81], [117, 118, 119, 120, 121, 122, 123, 124, 125], [130, 131, 132, 133, 134], [11, 12, 13, 14], [27], [58], [82, 83, 84, 85, 86, 87, 88, 89, 90], [135, 136, 137, 138, 139]]
# {'number_of_embedding_entry': 158,
#  'embedding_time': 32.276519775390625,
#  'embedding_time_per_entry': 0.20428177073032042,
#  'mean_hit@10': 0.6,
#  'map@10': 0.14523456790123457,
#  'mean_hit@5': 0.5,
#  'map@5': 0.11299999999999996,
#  'mean_hit@3': 0.4,
#  'map@3': 0.11111111111111112,
#  'mean_hit@1': 0.3,
#  'map@1': 0.3}

# %%
df.iloc[[49, 50, 51]].text.tolist()
# Out:
# ['เราก็จะ optimization pool นะครับ แต่อันนี้มันเวิร์คก็ต่อเมื่อ มันเป็นลีเนียร์ ถ้าไม่มีเนี่ยมันอาจจะ line เป๊ะไปหมดแต่เนื่องจากเรามีแต่เรารู้มาขยับ มาพูดถึง detination ของสิ่งที่เราจะเรียนกันในสภาพก็คือ renier program หรือ rear optimization ซึ่งโจทย์นี้คือโจทย์ media program มี program ก็คือโจทย์ที่ อิทิฟฟังก์ชันเป็นmediaนะครบ redio เมื่อเทียบกับ division',
#  'ก็คืออะไรคือ image ฟังก์ชันก็คือแบบคุณเขียนเป็น active ได้แล้วฝั่งนี้คือ decision bao อันนั้นคือ nation ของมีเดียเราต้องต้ม ยาหรือ constrain เป็น redio เหมือนกันนะแต่ว่าเป็น pedia คือ polity หรือ eity ก็ได้ นะครับ ที่นี้มีฟังก์ชันคืออะไรเนี่ยฟังก์ชันก็คือ รีบไปนอนรอบ เป็นการบวกกันออก ด้วย scary factor บางอย่าง remiarepicorlity ก็คือ renal function ที่เป็น ดีอีดีคอนิตี นะครับ',
#  'ข้อสังเกต คือ มันเป็นน้อยกว่าเท่ากับมากกว่าเท่ากับนะถ้า ถ้าเป็นแค่อย่างนี้หรืออย่างนี้ไม่ได้ไม่นับ อันนี้ถ้าเข้าเดสทิเนชั่นนี้จะกลายเป็นมีโปรแกรม หรือโจทย์ demel limitation จากลักษณะโจทย์นี้ นะครับจากลักษณะโจทย์นี้มันจะมี ฟังก์ชันที่อยู่ในโจทย์ อยู่ที่บางทีคุณอาจจะไม่ได้นึกถึงแต่ว่า เราก็จะมาไล่เป็นสี่ข้อที่คุณตั้งโจทย์แบบนี้นะแสดงว่าคุณมีฟังชั่นนี้อยู่ในโจทย์']

# %%
# df.iloc[[49, 50, 51]].text.tolist()
df.iloc[[49, 143, 107, 100, 54, 130, 95, 131, 122, 48]].text.tolist()
# Out:
# ['เราก็จะ optimization pool นะครับ แต่อันนี้มันเวิร์คก็ต่อเมื่อ มันเป็นลีเนียร์ ถ้าไม่มีเนี่ยมันอาจจะ line เป๊ะไปหมดแต่เนื่องจากเรามีแต่เรารู้มาขยับ มาพูดถึง detination ของสิ่งที่เราจะเรียนกันในสภาพก็คือ renier program หรือ rear optimization ซึ่งโจทย์นี้คือโจทย์ media program มี program ก็คือโจทย์ที่ อิทิฟฟังก์ชันเป็นmediaนะครบ redio เมื่อเทียบกับ division',
#  'จุด x ใดใดใน standard ฟอร์ม lp มันเขียนได้ด้วยรูปนี้ แล้วจุดเขียนในรูปนี้เสมอ ทีนี้เรามี เรามีเชียร์เล่นเยอะพอแล้ว ที่เราจะพบอันหนึ่งที่น่าสนใจนะครับก็คือว่า พบว่า ถ้า p มันออปติคอล ถ้าเป็นออม แอลพีนั้นน่ะ มัน optimal ที่ efs ถ้ามันออฟซิลมันอิมที่ดีเป็น ซึ่งอันนี้เป็นคีย์คีย์สำคัญมากมากที่ เป็นตัวรถ',
#  'เอหนึ่งแกนเริ่มเริ่มเสร็จเป็น เป็นสี่มิติเราคงไม่สามารถวาดได้แล้วแต่สุดท้ายในสี่มิตินี้เราหา เราหาจุดตัดใช่ปะจุดตัดมันตัดเส้นระนาบไปเชิงเทคนิค มันเป็นพื้นที่อะไรก็แล้วแต่ เพราะฉะนั้น วิธีที่เราจะทำนะครับ วิธีทำก็คือเฮ้ยแย่แล้วเรา มันมีคำตอบเยอะ ใช่ไหมมันมีคำตอบเยอะเกินคือ ในใน program ทั้งหมดนี้',
#  'นะครับก็จบแล้วง่ายมาก รอบบริเวณมีอาการผิดบางบ้าน จะแต่งกายและเป็น programming นี่ก็จะบอกว่าโดยที่แสดงความเป็นรูปเน้ เอ็กซ์แพนเวกเตอร์เอ็กซ์ได้แมคซีไมซีพีเอสซีเอ็กซ์ทับเจ็คคูเอเอ็กซ์น้อยกว่าเท่ากับบีแอนด์เอ็กซ์มากกว่าเท่ากับ แล้วแต่เราทำตามหนังสือเรา ปรับ จริงจริงแล้วไม่ standard เพราะว่าฟอร์มมันจะเป็นเท่ากับเราจะได้ soe ตรงตรงแต่ว่าการเปลี่ยนจากรูปนั้นเป็นรูปสแกนฟองมัน เอ่อ',
#  'untivationอันที่เป็นะ อีกอันนึงก็คือ stanley ก็คือมัน static มันไม่มี and มัน venti deviate อันนี้ก็คือบอกว่าเราเป็นเรากำลังเล่นอยู่บน note นะ ดูดิซิชั่นบาร์ของเลาเนี่ยต้องเป็นเศษสูรได้ ถ้าเป็นทศนิยม อันนี้คือ reit program ถัดมา เราก็จะมีพูดถึง destination ทางคณิตศาสตร์อันหนึ่งนะครับก็คือ conmat test อ่ะ อันนี้เป็นคณิตศาสตร์ซึ่งเดี๋ยวเราจะเอามาใช้รูปบ้าบอต่างต่าง',
#  'ค่อนข้างเราบอกว่ามีสี่ความเป็นไปได้ตามโปรแกรมได้ไหม solution solution multiple ไม่มี solution หรือ peiple and brown ผมขอพูดถึงอันนี้นึง เอา ผมจะ define อันนี้คือ define definition นะครับ สิ่งที่เรียกว่า direction of bound business คืออะไรนะครับอ่านก่อนอื่นก็บอกว่ามี standard ไอแอคอันนึงนะ นะครับแล้วก็มี pretiblewigiess ผมจะบอกว่า ดีเนี่ยคือ nonfever เวกเตอร์ d เป็น divationofanbundesnessi สำหรับ rx อยู่ใน s',
#  'จากเดิมมันเป็นสมการเอเอ็กซ์มากกว่าเท่ากับบีบคอแตกอะไรก็ไม่รู้แต่พอเราตัดเป็นแอร์ฟอร์มปุ๊บเอเอ็กซ์เท่ากับ พอได้อันนี้ปุ๊บเนี่ยเราก็ โยนเข้าเข้า to his อันนึงนะครับ to hit ซึ่งเราจะใช้ ใส่ photoptimizeกอนดิอ ซึ่งผมไปเคาะ screen shot ดอกเข้ามาตาย timon fox ย่อมาจาก dna programming ฟังก์ชันที่ทำลายฟังก์ชั่นนี้มินิหาย จากนั้นเราก็เลยต้องเปลี่ยนจาก maximize ก็กลายเป็น minimi นะครับโดยที่',
#  'ออร์ซีมากกว่านี้สามารถ เอา direction ไปบวกนะครับ จาก x และอยู่ใน คือยังไงสมมุติ ผมมี มีเยี่ยนอยู่ อีพีเอ ถ้าผมมีเวคเตอร์อันหนึ่ง เวกเตอร์สมมุติว่าผมเวกเตอร์หน้าตาแบบนี้ ผมบอกว่าผมหยิบ if x ใดใด แล้วผม บวก และ eton เข้าไป แล้วตอนที่มันบวก',
#  'มากกว่าหน้าศูนย์เนี่ย picibaladiaของผมคือ อันนี้อันนี้คือเส้น เส้นเท่ากับสิบ เส้นสีเหลือง เอ็กซ์หนึ่งบวกเอ็กซ์สองเท่ากับห้าเนี่ยคือระนาบ มาหน้า แล้วมันตัด ตัดกันเป็นโซนโซนหนึ่งนะครับ มีเส้น อันนั้นคือ principle retin ไม่ไปตัด อ่าน ถ้าผมโซหา dfs เนี่ย นะครับผมจะพบว่า ผมจะได้ dss จากโจทย์นี้สองจุดคือจุดนี้ ตัวนี้',
#  'หรือ active ของเราก็คือเป็นเส้นที่เส้นนี้นะไม่ว่าจะจุดใดก็ตามนี่ ออทิทีฟจะนเท่ากันหมดคือเส้นี้ออทิทีฟเราคือ หนึ่งเท่ากันหมด เส้นนี้พอทีเราคือสองเท่ากันหมด เพราะฉะนั้นมุมมอง electic ก็คือเราว่า file resin เราลาก iso profit line แล้วก็ดูการขยับของ oic line ด้วยมันขยับวิ่งอย่างนี้ oly ลงมา เรามาดูว่ามันขายไข่ไทยไปเรื่อยเรื่อยมัน มันชนกับ desible redial ครั้งสุดท้ายเมื่อไหร่']
