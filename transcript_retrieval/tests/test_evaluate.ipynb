# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import sys
import pandas as pd
from sentence_transformers import SentenceTransformer

sys.path.append("../")
from evaluation.evaluate import Evaluation

# %%
df = pd.read_csv("../data/labeled/labeled_transcript_04.csv", index_col=0)

# %%
model_name = 'sentence-transformers/paraphrase-multilingual-mpnet-base-v2'
# model_name = 'intfloat/multilingual-e5-large'
# model_name = 'mrp/SCT_Distillation_BERT_Base'
# model_name = "D:/Chula/Year4_2/capstone/mcv-smart-learning-tools/transcript_retrieval/simcse/saved_model/simcse-model-thai-version-1"
max_seq_length=128

model = SentenceTransformer(model_name)
model.max_seq_length = max_seq_length

# %%
evaluation = Evaluation()
evaluation.get_st_report(df, model, k_list=[10, 5, 3, 1])
# evaluation.get_st_report(df, model, k_list=[10])
# evaluation.mean_hit_k([49, 143, 107, 100, 54, 130, 95, 131, 122, 48], [49, 50, 51], 10)
# evaluation.mean_average_precision_k([49, 143, 107, 100, 54, 130, 95, 131, 122, 48], [49, 50, 51], 10)
# Out:
# Embedding context
# Batches:   0%|          | 0/7 [00:00<?, ?it/s]
# Predicting
#   0%|          | 0/4 [00:00<?, ?it/s]
# [[98, 88, 80, 85, 82, 99, 94, 53, 120, 146], [162, 160, 165, 202, 180, 163, 159, 157, 153, 164], [186, 182, 207, 41, 188, 164, 183, 197, 187, 51], [182, 191, 88, 82, 57, 86, 184, 93, 10, 120], [84, 82, 85, 80, 88, 86, 156, 96, 77, 191], [161, 80, 114, 85, 88, 179, 189, 156, 43, 78], [161, 96, 62, 84, 80, 43, 64, 85, 63, 97], [186, 125, 156, 162, 187, 84, 77, 172, 183, 169], [161, 160, 162, 202, 77, 159, 158, 180, 156, 154], [51, 52, 57, 53, 75, 183, 60, 76, 78, 44]]
# [[97, 98, 99, 100, 101, 103, 104, 105, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118], [159, 160, 161, 162, 167, 168, 169, 171, 176, 177, 178, 179, 180], [183, 184, 185, 186], [188, 189, 190, 191, 192], [80, 81, 82, 83, 84, 85, 86, 87, 88], [97, 98, 99, 100, 101, 103, 104, 105], [80, 81, 82, 83, 84, 85, 86, 87, 88], [121, 122, 123, 124, 125, 126, 127, 128, 129], [161, 162, 163, 164, 165, 166, 167, 168, 169, 170, 171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181], [183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199, 200, 204, 205, 206, 207]]
# [[98, 88, 80, 85, 82], [162, 160, 165, 202, 180], [186, 182, 207, 41, 188], [182, 191, 88, 82, 57], [84, 82, 85, 80, 88], [161, 80, 114, 85, 88], [161, 96, 62, 84, 80], [186, 125, 156, 162, 187], [161, 160, 162, 202, 77], [51, 52, 57, 53, 75]]
# [[97, 98, 99, 100, 101, 103, 104, 105, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118], [159, 160, 161, 162, 167, 168, 169, 171, 176, 177, 178, 179, 180], [183, 184, 185, 186], [188, 189, 190, 191, 192], [80, 81, 82, 83, 84, 85, 86, 87, 88], [97, 98, 99, 100, 101, 103, 104, 105], [80, 81, 82, 83, 84, 85, 86, 87, 88], [121, 122, 123, 124, 125, 126, 127, 128, 129], [161, 162, 163, 164, 165, 166, 167, 168, 169, 170, 171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181], [183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199, 200, 204, 205, 206, 207]]
# [[98, 88, 80], [162, 160, 165], [186, 182, 207], [182, 191, 88], [84, 82, 85], [161, 80, 114], [161, 96, 62], [186, 125, 156], [161, 160, 162], [51, 52, 57]]
# [[97, 98, 99, 100, 101, 103, 104, 105, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118], [159, 160, 161, 162, 167, 168, 169, 171, 176, 177, 178, 179, 180], [183, 184, 185, 186], [188, 189, 190, 191, 192], [80, 81, 82, 83, 84, 85, 86, 87, 88], [97, 98, 99, 100, 101, 103, 104, 105], [80, 81, 82, 83, 84, 85, 86, 87, 88], [121, 122, 123, 124, 125, 126, 127, 128, 129], [161, 162, 163, 164, 165, 166, 167, 168, 169, 170, 171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181], [183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199, 200, 204, 205, 206, 207]]
# [[98], [162], [186], [182], [84], [161], [161], [186], [161], [51]]
# [[97, 98, 99, 100, 101, 103, 104, 105, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118], [159, 160, 161, 162, 167, 168, 169, 171, 176, 177, 178, 179, 180], [183, 184, 185, 186], [188, 189, 190, 191, 192], [80, 81, 82, 83, 84, 85, 86, 87, 88], [97, 98, 99, 100, 101, 103, 104, 105], [80, 81, 82, 83, 84, 85, 86, 87, 88], [121, 122, 123, 124, 125, 126, 127, 128, 129], [161, 162, 163, 164, 165, 166, 167, 168, 169, 170, 171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181], [183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199, 200, 204, 205, 206, 207]]
# {'number_of_embedding_entry': 221,
#  'embedding_time': 10.7279634475708,
#  'embedding_time_per_entry': 0.04854282102973213,
#  'mean_hit@10': 0.9,
#  'map@10': 0.5291269841269842,
#  'mean_hit@5': 0.8,
#  'map@5': 0.6025,
#  'mean_hit@3': 0.7,
#  'map@3': 0.5833333333333333,
#  'mean_hit@1': 0.5,
#  'map@1': 0.5}

# %%
df.iloc[[98, 88, 80, 85, 82, 99, 94, 53, 120, 146]].text.tolist()
# Out:
# ['ทุกทุกคาบถูกไหมมันจะเริ่มกลับมาซ้ำที่เดิมทุกทุกคาบนะแปลว่าเอ็กซ์ทีเนี่ยนะแล้วถ้าขยับไปเอ็นทีเนี่ยมันจะต้องกลับมาซ้ำเท่าเดิมอีกและถูกไหม เพราะฉะนั้นถ้าเอ็กพีเท่ากับเอ็กพีบวกเอ็นที ทั้งหมดทั้งมวลเลยของตัวซิกแนลเนี่ยก็คือมันเป็นคลีนิกนั่นเองนะคะก็คือมีการซ้ำ นะครับ เอ็นนี่ว่ากี่เท่าของข้าก็ได้ใช่ไหม แล้วตัวที่ที่ว่ามาซ้ำกันนะคะ จะเรียกว่าเป็น fundamental period',
#  'ค่าที่หนึ่งบวกกับลบจะเป็นครึ่งหนึ่งแต่ว่าเขาไม่ค่อยพูดถึงนะคะไม่ค่อยพูดถึงแต่ในหนังสือไม่บอกนะคะถ้าอ้างอิง โอเคที่นี้รู้จักคำว่าคอนนิวอัสทาร์แล้วเนาะพูดง่ายง่ายว่าเออก็สัญญาณต่อเนื่องนั่นแหละไม่มีอะไรนะคะสัญญาณสี่เหลี่ยมก็ยังเป็นคอนทินิวอัสทาร์นะคะแต่ว่าไม่ได้คอนทินิวอัส ไม่ใช่คอนนียาซิแนลรอเปอร์เซ็นต์น ทีนี้สัญญาณสี่เหลี่ยมนะเรามาทำความรู้จักกันในรูปของการ define นะบางทีก็ใช้คำนี้ค่ะคำว่าเว็บ แล้วก็',
#  'หลักที่สำคัญเลยการแบ่งซิกแนลก่อนแล้วกันนะเราก็จะในวิชานี้อาจารย์จะพูดถึงซิกแนลทั้งสองแบบก็คือจะเป็นคนนะคะกับรีไทม์นะคะจะเห็นว่ามีคำว่ามีไทม์ด้วยนะคะ ที่สงสัยว่าแล้วมันต่างกับคอนทินิวซิกแนลไหมต่างกับคอนทินิวอัสซิกแนลไหมซิกแนลก็คือฟังดูเป็น ซีนนี้ต้องคอนทินิวอัสใช่ไหมแต่ว่าแต่ยังไงตัวแรกก่อนเลยนะเงื่อนไขที่หนึ่งคอนทินิวอัสไทม์ซิกแนล',
#  'บริเวณที่หนึ่งบวกนี่มันไม่เท่ากับที่หนึ่งลบนะนะคะกรณีนี้จะเห็นว่าสัญญาเนี่ยจะไม่เรียกว่าเป็น continuous จะไม่เรียกว่าเป็นคนมา สัญญาณยังเป็นคอนทาทาเนาะนะคะเพราะว่ามันต่อเนื่องกันในทุกช่วงเวลา แบบนี้จะเรียกว่าเป็นแบบ มีบางส่วนที่คอนทินิวอัสนะคะเขาจะเรียกว่าเป็นพีชายคอนนิวส์ ซึ่งสัญญาณความหิวอาสาก็คือสัญญาณอนาล็อกทั่วไปที่เราเจอเนาะเวลาที่อาจารย์พูดมันไม่ได้ขาดเป็นแบบปักปักปักอะไรอย่างนี้ใช่ไหมมันแบบมันมีการ',
#  'ตัวนี้จะเรียกว่าเป็นคอนนิวอัสทาน์นะนครนีอัสทาน์ ที่นี่นะคะแต่ว่าถ้าจะพูดถึงสัญญาณคอนดิวอัสเลยนะคะจะมีอีกมุมนึงที่ให้ดูก็คือว่าสมมุติว่าเราพิจารณา สัญญาณที่เวลา t หนึ่งอย่างนี้ที่หนึ่ง หนัง การที่สัญญาเนี่ยจะเป็น continuous ตัวทีจะต้องคอนเทสแล้วนะคะตัวเอ็กซ์ทีก็คือตัวสั่งฆ่าของสัญญาณเอง จะต้อง continuous ด้วยนะคะทุกทีความหมายก็คือว่าสมมุติว่าเรามีสัญญาณขึ้นแบบนี้นะคะแล้วเราพิจารณาที่เวลาใดเวลาหนึ่งเช่นที่หนึ่ง',
#  'จริงจริงก็คือจุดที่สั้นที่สุดอ่ะที่มันจะเริ่มซ้ำกันอ่ะนะนะคะระยะทางที่ระยะเวลาที่สั้นที่สุดที่จะเริ่มซ้ำกันอะเนาะก็จะเป็น fundamental period แล้วก็ทีเนี่ยต้องมากกว่าส่วนเสมอด้วยนะภาพมันไม่มีน้อยกว่าศูนย์ ตัวอย่างก็เช่นสัญญาณไซน์เวฟ ตัวนี้ ก็เวลาเราวาดสัญญาณไซน์เวฟนะยังจำกันได้ไหมว่าว่ายังไง สันดานทรายที่ศูนย์นี่เป็นหนึ่งหรือศูนย์ หนึ่งหรือศูนย์ศูนย์แต่ว่าไซน์เวย์เป็นอย่างไร',
#  'แค่ตัวเรนแต่ว่าพอเป็นดิฟพรีดอ่ะเราจะใช้สัญลักษณ์จากวงเล็บโค้งเนาะก็จะเป็นวงเล็บสี่เหลี่ยม ฉะนั้นเวลาเราพูดถึงสัญญาณดิฟครีทไทม์เนี่ยก็จะเป็นเอ็กซ์เคยนะคะหรือเดี๋ยวเราจะเจอเป็นเอ็กซ์เอ็นเนี่ยเป็นหลักเลยนะเอ็นก็เหมือนแบบตัวที่เท่าไหร่แล้วอะไรเงี้ยตัวเวลาที่ เพราะเราพูดถึง เหมือนกับตัวแปรหลักของเราเป็นตัวเวลานะก็จะเป็นเวลาที่เอ็นเป็นลบสองลบหนึ่งศูนย์หนึ่งสองซึ่งนี่ก็คือเป็นอินเตอร์นั่นเองนะ เอ็มเป็น inter',
#  'อธิบายว่า furia transform output น่ะมันบอกอะไรเราบ้าง หลักหลักแค่นี้นะวิชานี้แต่เพียงแต่ว่ากว่าจะเดินทางไปถึงจุดสุดท้ายนี่มันอาจจะมีที่มาที่ไปนิดนึงนะแล้วก็เลยคิดเป็นหกคุยได้ นะจริงจริงหลักหลักมีแค่นี้นะนะคะไลฟ์ความถี่อย่างนั้น อันนี้ก็จะเป็นเลนส์ว่า settle ของเราจะเป็นยังไงบ้างวันนี้คือวันที่เราแบบเจอกันเนาะวันนี้วันที่เราเจอกัน',
#  'สองพายโอเมก้าศูนย์ทีก็คือโอเมก้าศูนย์ทีนั่นเองนะคะ ตรงนี้นะนะเราก็จะเห็น คอร์สอยู่ตรงนี้นะคะแต่ว่าเป็นแกน imaginary เราจะเห็นสไตล์ตรงนี้นะคะซึ่งถ้ามันจะเปลี่ยนแปลงไปตามทางก็คือเวลาตรงนี้นั่นเองนะคะมันก็จะตีเป็นเกลียวแบบนี้นะคะแต่ว่าคงมองไม่เห็นเพราะว่ามันเป็นคอมเพลค พาร์ทคอมเพล็กซ์ก็มองไม่เห็นนะคะแต่ว่ามัน',
#  'เมื่อสักครู่มีเพื่อนเพื่อนมาสอบถามเหมือนกันนะคะในหัวข้อวันนี้มันจะมีความเป็นต่อมต่อมนิดหน่อยนะเบื้องต้นอ่ะจารย์อยากให้เรารู้จักแบบแต่ละ component อะไรเช่น conditinal คืออะไร dii final คืออะไรคืออะไรจะหาสัญญาณ apple ยังไง นะคะแล้วก็มันอาจจะยังไม่ได้มีสตอรี่เชื่อมกันมากไรเงี้ยนะคะส่วนเจ้าตัว complex expo เมื่อสักครู่ที่บอกว่าเป็นพระเอกก็จริงเนาะแต่ถ้าใครยังแบบ ไม่รู้สึกคุ้นชินกับมันน่ะก็ไม่แปลกนะนะคะแต่เบื้องต้นน่ะก็มองว่าเป็นฟังก์ชั่นนึงแล้วกันนะเป็น']

# %%
# df.iloc[[49, 50, 51]].text.tolist()
df.iloc[[97, 98, 99, 100, 101, 103, 104, 105, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118]].text.tolist()
# Out:
# ['อยากได้ยินคำตอบว่าแบบนี้เลยก็เวลาพูดถึงภาพนะคะก็แน่นอนว่าเราจะ represent ว่าสัญญาณมีค่าเท่าไหร่อ่ะแบบนึงเลยก็คือเราสามารถเล็กพรีเซ็นต์ได้เป็นไซนูไซดอลwaveนะคะหรือว่าจะเป็นไทร์หรือคอร์สก็ได้หรือคอร์สฟังก์ชั่นก็ได้ ก่อนอื่นเลยนะคำว่า สัญญาณที่เป็นภาพแปลว่าอะไรนะแปลว่าสมมุติว่าวาดง่ายง่ายนะสัญญาสักตัวนึงเนาะสัญญานี่จะเริ่มกลับมาซ้ำที่เดิมเนี่ยนะคะทุกทุก',
#  'ทุกทุกคาบถูกไหมมันจะเริ่มกลับมาซ้ำที่เดิมทุกทุกคาบนะแปลว่าเอ็กซ์ทีเนี่ยนะแล้วถ้าขยับไปเอ็นทีเนี่ยมันจะต้องกลับมาซ้ำเท่าเดิมอีกและถูกไหม เพราะฉะนั้นถ้าเอ็กพีเท่ากับเอ็กพีบวกเอ็นที ทั้งหมดทั้งมวลเลยของตัวซิกแนลเนี่ยก็คือมันเป็นคลีนิกนั่นเองนะคะก็คือมีการซ้ำ นะครับ เอ็นนี่ว่ากี่เท่าของข้าก็ได้ใช่ไหม แล้วตัวที่ที่ว่ามาซ้ำกันนะคะ จะเรียกว่าเป็น fundamental period',
#  'จริงจริงก็คือจุดที่สั้นที่สุดอ่ะที่มันจะเริ่มซ้ำกันอ่ะนะนะคะระยะทางที่ระยะเวลาที่สั้นที่สุดที่จะเริ่มซ้ำกันอะเนาะก็จะเป็น fundamental period แล้วก็ทีเนี่ยต้องมากกว่าส่วนเสมอด้วยนะภาพมันไม่มีน้อยกว่าศูนย์ ตัวอย่างก็เช่นสัญญาณไซน์เวฟ ตัวนี้ ก็เวลาเราวาดสัญญาณไซน์เวฟนะยังจำกันได้ไหมว่าว่ายังไง สันดานทรายที่ศูนย์นี่เป็นหนึ่งหรือศูนย์ หนึ่งหรือศูนย์ศูนย์แต่ว่าไซน์เวย์เป็นอย่างไร',
#  'แต่ถ้าคอร์สก็เริ่มตรงนี้นะใช่ไหมไซน์เวฟนะแต่ทีนี้เขาบอกว่าสมมติอาจารย์จะวาด exe นะนะคะเจ้าตัวนี้ ในวิชานี้มันมีต้องวาดรูปด้วยนะนะคะก็ suggest นิดนึงแล้วกันเนาะใครได้เรียนดรออิ้งมาไม่เกี่ยวนะคนวาดรูปกันนะแต่ว่าก็คือเราจะต้อง step นิดนึงนะคะก็อย่างกรณีนี้เราก็จะรู้เลยว่า',
#  'ตัว frequency ของเขาเนาะอันนี้น่าจะพอจำได้นะว่าถ้ากรณีนี้เนี่ยสัญญาณไซน์เนี่ยจะมีแอมพลิจูดเป็นแอมพลิจูดก็คือตรงส่วนนี้ถูกไหมมีค่าเป็น อาการ เอาล่ะแฮงล่ะคงต้องปิด คู่นะ ปีนี้มีอุปสรรคเยอะคอม มองเพลงบ่อยมาก ทางไปแล้ว ช่วงนี้ถือว่าพักแป๊บนึงก็ได้นะเปิดเปิดแอปใหม่แป๊บนึง การค้นพบว่าต้องปิดให้หมดทุกแอปพูดโน๊ตถึงการเวิร์คอะไร',
#  'โอเคนะคะก็แน่นอนว่าตอนนี้ก็คือจะเรียกได้ว่าเป็นเรเดียนฟีเควนซีเนาะนะคะเวลาพูดถึงความถี่ก็จะมีความถี่ที่เป็นเรเดียนคนใช่ไหมคะซึ่งจะเท่ากับถ้าใครจำได้นะสองพายใช่ไหมซึ่ง จะเท่ากับสองพาทีด้วยจำได้ไหมคุณนี่ก็จะเป็น fundamental ii แล้วนั่นเองนะคะแล้วนี่ก็จะเป็นความถี่ซึ่งเป็นหนึ่งส่วนที่นั่นเองเราสามารถพูดถึงความถี่ได้สองแบบนะความถี่เป็นเชิงเรเดียน หรือว่าความถี่ที่เป็นหน่วย ใช่ไหมหนึ่งส่วน อาจจะเป็นเซ็คเอ็น',
#  'มีอะไรเกิดขึ้น โอเคโอเคใช่ไหม ไปโดนปุ่ม นะ โอเมก้าศูนย์เมื่อกี้เขียนตรงนี้ไปแหละโอเมก้าศูนย์เท่ากับสองไอเอฟเท่ากับสองไพส่วนที่นะคะเอฟก็เป็นหน่วยเฮิร์นโอเมก้าก็จะเป็นเรเดียนเปอร์เซคนั่นเองนะคะเราเขียนได้อธิบายความถี่ได้สองแบบซึ่งเดี๋ยวก็จะเจอเหมือนกันนะคะ ที่นี้มันก็จะมีเฟสด้วยนะนะคะก็แล้วแต่ว่าสัญญาณมันเลื่อนไปเท่าไหร่นะอันนี้ก็จะเป็นหน่วยที่เป็นเฟสนี้ก็คือหน้าตาสัญญาณของเราที่มีความสูงเป็นเอแล้วก็มีเฟส',
#  'ไฟล์แบบนี้นะคะรูปนี้วาดได้แบบนี้เลย ดูออกไหมสัญญาณทรายนะซึ่งจริงจริงมันก็จะ repeat ด้วยนะคะแต่ว่าเฟสมันก็จะขยับไปจากจุดศูนย์น่ะใส่ศูนย์ไปด้วย ไประดับหนึ่งอะไรอย่างเนี้ยนะ นี้แน่นอนว่าถ้าเราต้องการหาคาบก็สองพายส่วนโอเมก้าศูนย์แต่ว่าใส่แอ็คสุดข้อนิดนึงเพราะว่ามีโอกาสที่ความถี่เชิงมุมเนี่ยมันอาจจะกลับด้านได้นะนะคะอาจจะเป็นลบได้มีเครื่องหมาย',
#  'โอเคไหม หรือไม่อยากจด เหนื่อยจัดอะไรก็มีนะนะคะบางคน แต่ก็มีสูตรให้ได้ดีสุด ว่ากันนะนะคะบอกว่าจะมาสายก็เลยไปเลยหนึ่งส่วนสองเริ่มที่หนึ่งว่าคอร์สที่ปกติเป็นหนึ่งที่เวลาศูนย์ สูตรตรงนี้หมดเลย ก็หนึ่งส่วนสองเริ่มตรงนี้เลยทีนี้อันนี้ความกว้างสองพายนะแปลว่าค่าเป็นเท่าไหร่นะนะคะค่าก็จะเป็นสองพายส่วนแอปรูทโอเมก้าศูนย์นะนะคะข้อนี้ก็สองพันส่วนสองห้าหนึ่งง่ายจังนะคะก็แปลว่าต้องครบคาบ',
#  'ตอนที่หนึ่งวินาทีก็จะใส่หนึ่งวินาทีไว้ตรงนี้เลย ครบคาบเลิกตรงนี้ใช่ไหมลงครบแล้วยังครบแล้วนะ เช่นเดียวกันกับทงซ้ายเหมือน อันนี้ข้อหนึ่งนะคะมีข้อสองปุ๊บคราวนี้ได้ไปถึงหนึ่งเลยนะคะแต่ว่าคาบในข้อสองเนี่ยมันก็จะเป็นสองพายส่วนสี่พายนะก็คือเป็นศูนย์จุดห้า ผอมหรือว่าอ้วนนะ หอมน้ำอ้วน ผอมเนอะเพราะว่าคราบมันเล็กกว่าตัวนี้ใช่ไหมน่าจะผอมหน่อย ก็น่าจะประมาณนี้',
#  'เราว่าครึ่งเดียว ตัวที่สามก็เศษสองส่วนสาม อยากให้แบบค่อยทำแต่ว่าเดี๋ยวมีโจทย์ให้ทำเยอะแยะเลยนะคะสองคนสาม พอเป็นคีย์สามปึ๊บ ค่า จะได้เป็น สองพายถ้าจะเป็นสองพายส่วนพายนั่นเองนะก็ได้สองเลยอันนี้แปลว่าอันนี้น่าจะอ้วนนะก็จะใหญ่ประมาณนี้เลย อันนี้ไกลไปนิดนึง เพราะว่าความสูงเป็นสองส่วนสาม ประมาณนี้นะนะคะก็สัญญาณรูปแบบต่างต่าง',
#  'เวลาที่เราไปทะเลใช่ไหมเราก็เห็นคลื่นน้ำก็จะมีคลื่นที่ความถี่มากความถี่น้อย ผสมกันไปมีใครสังเกตไหม ดีนะต่อไปเราไปทะเลเราก็จะนึกถึงซิกเนล ฟูเรีย transform โอเคอันนี้เราก็รู้จักสัญญาแล้วเนาะนะคะที่นี้เรามารู้จักพระเอกของ transform กันนิดนึงแล้วกันนะคะก็คือ เจ้าตัวนี้นั่นเองนะคะ ตัวนี้นะคะเขาชื่อว่า คอมเพล็กซ์เอกซ์โปเนนเชียลคอมเพลคเอกซ์โปเนนเชียล',
#  'คอมเทคอกโฟเนเชียล ถ้าที่เราเคย ก็คือหน้าตาเป็นตัวนี้เนาะ อียกกำลังเจอเมกาที ที่นี้โจทย์ข้อนี้เขาบอกว่าถ้าเรามีฮาโมนิคแปลว่าเป็นเอ็กซ์โปที่เป็นคอนนิวอนเอ็กซ์โฟที่ตัวแปรเป็นทีนะคะ แล้วมีฮาร์โมนิครีรีเรเตรทเมือกลืมพูดเรืองฮาโมนิคก็คือสมมติว่าเรามีความถี่ อยู่ตรงไหนวะ ฮาร์โมนิคมีใครเห็นไหมอะไร เอ่อ ที่ที่สัญญานะนะคะที่มี',
#  'ที่มีความถี่ต่างต่างนะพี่ก็นึกถึงเสียงเพลงก็ได้ ความถี่ต่างต่างเรารู้ว่า fundamental enc เนี่ยก็คือจะเป็นโอเมก้าศูนย์โอเมก้าศูนย์มีค่าเป็นคีย์ความถี่เป็นเอฟศูนย์อะไรก็ว่าไปนะคะแต่ที่นี่เนี่ยนะคะถ้าเป็นความถี่ที่สูงขึ้นนะคะมีเจ้าตัว เป็นตัวเคเท่าของความถี่โอเมก้าศูนย์เนี่ยนะคะเราก็จะเรียกว่าเป็นฮาร์โมนิคที่ต่างต่างต่างต่าง ฮาร์โมนิค ที่นี้เนี่ยนะคะซึ่ง',
#  'ในโจทย์ข้อนี้เขาบอกว่าถ้าเรามีสัญญาณตัวนึงนะที่เป็น complex exponential นะนะคะแล้วเนี่ยเขามีหน้าตาแบบนี้นะคะอีกกำลังเจเคโอเมก้าศูนย์ทีซึ่งจริงจริงถ้าเราแอบเรียน จำตอนที่เรียนมาได้เนาะนะคะก็คือน่าจะเป็นออยเลอร์ formula ใช่ใช่ปะชื่อนี้ปอล์ไม่แน่ใจ ที่เป็นอียกกำลังเจ็ดซีตาร์ใช่ไหมเท่ากับคอส ซีตาร์บวกเจทรายสีตา ทุกคนรู้ไหมว่าคืออะไรน่ะพอดีปีก่อนมีคนถามตอนผ่านไปสักพักคืออะไร',
#  'คืออะไรคะ imaginary ใช่ไหมก็คือจากข้างหน้าจะเป็นเรียนเป็นเรานะคะแล้วก็แล้วก็ก็หลังจะเป็น imaginary part ใช่ไหมคะซึ่งเราอาจจะไม่ได้เห็นในชีวิตจริง แต่ว่ามันมัน มันซ่อนอยู่ในสัญญานะนะคะแล้วก็เอาไว้ใช้ในการคำนวณด้วยนะคะถูกไหม แล้วก็ในแต่ละสัญญามันก็อาจจะมีเฟสของมันนะซึ่งก็คือจะเป็น',
#  'เป็นลักษณะที่เป็นจำนวนเชิงซ้อนนั่นเองนะคะเพราะฉะนั้นในการคำนวณเนี่ยเราในวิชานี้ก็เลยแบบไม่ได้แค่คอนเสิร์ตแค่ real number นะคะก็จะมีส่วนของคอมเพล็กซ์ด้วยนะซึ่งถ้าสังเกตเห็นว่าเจ้าตัว complex expo ที่บอกว่าเป็นพระเอกตัวนี้นะคะเขาก็จะมี คุณสมบัติที่ผสมผสานระหว่างคอร์สกับทรายอยู่แล้วนะคะผสมผสานระหว่างคอร์สกับทราย โดยที่ถ้าเรามองในแกนเรียวนะก็จะเห็นเป็นคอร์สแต่ถ้ามองในแกนอีแมซินารี่จะเห็นเป็นทราย',
#  'แล้วก็ถ้าเราแทนค่าข้างในลงไปในอีกกำลังจะซีต้าซีต้าร์ตัวนี้ก็คือจะเป็นโอเมก้าศูนย์ที่ถูกไหม ถูกไหมคะเช่นเดียวกันกับตัวเจทรายเหมือนกันนะคะเจไซ์เคโอเมก้าศูนย์ทีน เพราะฉะนั้นเราสามารถที่จะหาความถี่ของสัญญาณนี้ได้เลยของสัญญาณนี้ได้เลยนะ จากการที่เรารู้ว่าอ๋อนะคะเจ้าตัวพีเรียดก็จะเท่ากับสองพายหารด้วยแอบโซลูทตัวตัว fundametal แฟนซีนะซึ่งตรงนี้ก็คือจะเป็นโอเมก้าศูนย์']
